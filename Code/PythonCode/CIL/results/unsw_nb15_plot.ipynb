# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
unsw_nb15_finetune = json.load(open("./unsw-nb15_finetune_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_finetune = [i[2] for i in unsw_nb15_finetune]
unsw_nb15_der = json.load(open("./unsw-nb15_der_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_der = [i[2] for i in unsw_nb15_der]
unsw_nb15_memo = json.load(open("./unsw-nb15_memo_unsw_nb15_memo_ann_128_Accuracy_curve.json"))
unsw_nb15_memo = [i[2] for i in unsw_nb15_memo]
unsw_nb15_lwf = json.load(open("./unsw-nb15_lwf_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_lwf = [i[2] for i in unsw_nb15_lwf]
unsw_nb15_icarl = json.load(open("./unsw-nb15_icarl_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_icarl = [i[2] for i in unsw_nb15_icarl]
print("Finetune")
print("Avg: ", np.mean(unsw_nb15_finetune))
print("Last:", unsw_nb15_finetune[-1])
print("DER")
print("Avg: ", np.mean(unsw_nb15_der))
print("Last:", unsw_nb15_der[-1])
print("MeMO")
print("Avg: ", np.mean(unsw_nb15_memo))
print("Last:", unsw_nb15_memo[-1])
print("Lwf")
print("Avg: ", np.mean(unsw_nb15_lwf))
print("Last:", unsw_nb15_lwf[-1])
print("Icarl")
print("Avg: ", np.mean(unsw_nb15_icarl))
print("Last:", unsw_nb15_icarl[-1])
# Out:
# Finetune
# Avg:  42.72199926376343
# Last: 1.440000057220459
# DER
# Avg:  72.14399948120118
# Last: 68.12999725341797
# MeMO
# Avg:  71.56199798583984
# Last: 66.62999725341797
# Lwf
# Avg:  65.49799957275391
# Last: 57.209999084472656
# Icarl
# Avg:  72.71399993896485
# Last: 64.88999938964844

# %%
plt.plot(unsw_nb15_der, label="der")
plt.plot(unsw_nb15_finetune, label="finetune")
plt.plot(unsw_nb15_memo, label="memo")
plt.plot(unsw_nb15_lwf, label="lwf")
plt.plot(unsw_nb15_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("unsw_nb15_accy.png")

# %%
unsw_nb15_der = json.load(open("./unsw-nb15_der_1000_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_der = [i[2] for i in unsw_nb15_der]
unsw_nb15_memo = json.load(open("./unsw-nb15_memo_1000_unsw_nb15_memo_ann_128_Accuracy_curve.json"))
unsw_nb15_memo = [i[2] for i in unsw_nb15_memo]
unsw_nb15_icarl = json.load(open("./unsw-nb15_icarl_1000_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_icarl = [i[2] for i in unsw_nb15_icarl]
print("DER")
print("Avg: ", np.mean(unsw_nb15_der))
print("Last:", unsw_nb15_der[-1])
print("MeMO")
print("Avg: ", np.mean(unsw_nb15_memo))
print("Last:", unsw_nb15_memo[-1])
print("Icarl")
print("Avg: ", np.mean(unsw_nb15_icarl))
print("Last:", unsw_nb15_icarl[-1])
# Out:
# DER
# Avg:  69.71400146484375
# Last: 64.51000213623047
# MeMO
# Avg:  69.13600006103516
# Last: 63.369998931884766
# Icarl
# Avg:  70.46999969482422
# Last: 62.97999954223633

# %%
plt.plot(unsw_nb15_der, label="der")
plt.plot(unsw_nb15_memo, label="memo")
plt.plot(unsw_nb15_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("unsw_nb15_accy_1000.png")

# %%
unsw_nb15_finetune = json.load(open("./unsw-nb15_finetune_500_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_finetune = [i[2] for i in unsw_nb15_finetune]
unsw_nb15_der = json.load(open("./unsw-nb15_der_500_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_der = [i[2] for i in unsw_nb15_der]
unsw_nb15_memo = json.load(open("./unsw-nb15_memo_500_unsw_nb15_memo_ann_128_Accuracy_curve.json"))
unsw_nb15_memo = [i[2] for i in unsw_nb15_memo]
unsw_nb15_icarl = json.load(open("./unsw-nb15_icarl_500_unsw_nb15_ann_128_Accuracy_curve.json"))
unsw_nb15_icarl = [i[2] for i in unsw_nb15_icarl]
print("Finetune")
print("Avg: ", np.mean(unsw_nb15_finetune))
print("Last:", unsw_nb15_finetune[-1])
print("DER")
print("Avg: ", np.mean(unsw_nb15_der))
print("Last:", unsw_nb15_der[-1])
print("MeMO")
print("Avg: ", np.mean(unsw_nb15_memo))
print("Last:", unsw_nb15_memo[-1])
print("Icarl")
print("Avg: ", np.mean(unsw_nb15_icarl))
print("Last:", unsw_nb15_icarl[-1])
# Out:
# Finetune
# Avg:  66.09599914550782
# Last: 56.869998931884766
# DER
# Avg:  67.67600021362304
# Last: 61.849998474121094
# MeMO
# Avg:  66.44399948120117
# Last: 59.77000045776367
# Icarl
# Avg:  68.0359992980957
# Last: 59.65999984741211

# %%
plt.plot(unsw_nb15_der, label="der")
plt.plot(unsw_nb15_finetune, label="finetune")
plt.plot(unsw_nb15_memo, label="memo")
plt.plot(unsw_nb15_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("unsw_nb15_accy_500.png")
