# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
ton_iot_network_finetune = json.load(open("./ton-iot-network_finetune_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_finetune = [i[2] for i in ton_iot_network_finetune]
ton_iot_network_der = json.load(open("./ton-iot-network_der_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_der = [i[2] for i in ton_iot_network_der]
ton_iot_network_memo = json.load(open("./ton-iot-network_memo_ton_iot_network_memo_ann_128_Accuracy_curve.json"))
ton_iot_network_memo = [i[2] for i in ton_iot_network_memo]
ton_iot_network_lwf = json.load(open("./ton-iot-network_lwf_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_lwf = [i[2] for i in ton_iot_network_lwf]
ton_iot_network_icarl = json.load(open("./ton-iot-network_icarl_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_icarl = [i[2] for i in ton_iot_network_icarl]
print("Finetune")
print("Avg: ", np.mean(ton_iot_network_finetune))
print("Last:", ton_iot_network_finetune[-1])
print("DER")
print("Avg: ", np.mean(ton_iot_network_der))
print("Last:", ton_iot_network_der[-1])
print("MeMO")
print("Avg: ", np.mean(ton_iot_network_memo))
print("Last:", ton_iot_network_memo[-1])
print("Lwf")
print("Avg: ", np.mean(ton_iot_network_lwf))
print("Last:", ton_iot_network_lwf[-1])
print("Icarl")
print("Avg: ", np.mean(ton_iot_network_icarl))
print("Last:", ton_iot_network_icarl[-1])
# Out:
# Finetune
# Avg:  48.097999572753906
# Last: 27.610000610351562
# DER
# Avg:  99.8979995727539
# Last: 99.70999908447266
# MeMO
# Avg:  77.28600006103515
# Last: 66.68000030517578
# Lwf
# Avg:  42.144000911712645
# Last: 21.200000762939453
# Icarl
# Avg:  99.82000122070312
# Last: 99.61000061035156

# %%
plt.plot(ton_iot_network_der, label="der")
plt.plot(ton_iot_network_finetune, label="finetune")
plt.plot(ton_iot_network_memo, label="memo")
plt.plot(ton_iot_network_lwf, label="lwf")
plt.plot(ton_iot_network_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("ton_iot_network_accy.png")

# %%
# Exemplar size 1000
ton_iot_network_der = json.load(open("./ton-iot-network_der_1000_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_der = [i[2] for i in ton_iot_network_der]
ton_iot_network_memo = json.load(open("./ton-iot-network_memo_1000_ton_iot_network_memo_ann_128_Accuracy_curve.json"))
ton_iot_network_memo = [i[2] for i in ton_iot_network_memo]
ton_iot_network_icarl = json.load(open("./ton-iot-network_icarl_1000_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_icarl = [i[2] for i in ton_iot_network_icarl]
print("DER")
print("Avg: ", np.mean(ton_iot_network_der))
print("Last:", ton_iot_network_der[-1])
print("MeMO")
print("Avg: ", np.mean(ton_iot_network_memo))
print("Last:", ton_iot_network_memo[-1])
print("Icarl")
print("Avg: ", np.mean(ton_iot_network_icarl))
print("Last:", ton_iot_network_icarl[-1])
# Out:
# DER
# Avg:  99.75999908447265
# Last: 99.16999816894531
# MeMO
# Avg:  97.18600006103516
# Last: 87.23999786376953
# Icarl
# Avg:  99.5760009765625
# Last: 98.91999816894531

# %%
plt.plot(ton_iot_network_der, label="der")
plt.plot(ton_iot_network_memo, label="memo")
plt.plot(ton_iot_network_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("ton_iot_network_accy_1000.png")

# %%
# Exemplar size 500
ton_iot_network_finetune = json.load(open("./ton-iot-network_finetune_500_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_finetune = [i[2] for i in ton_iot_network_finetune]
ton_iot_network_der = json.load(open("./ton-iot-network_der_500_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_der = [i[2] for i in ton_iot_network_der]
ton_iot_network_memo = json.load(open("./ton-iot-network_memo_500_ton_iot_network_memo_ann_128_Accuracy_curve.json"))
ton_iot_network_memo = [i[2] for i in ton_iot_network_memo]
ton_iot_network_icarl = json.load(open("./ton-iot-network_icarl_500_ton_iot_network_ann_128_Accuracy_curve.json"))
ton_iot_network_icarl = [i[2] for i in ton_iot_network_icarl]
print("Finetune")
print("Avg: ", np.mean(ton_iot_network_finetune))
print("Last:", ton_iot_network_finetune[-1])
print("DER")
print("Avg: ", np.mean(ton_iot_network_der))
print("Last:", ton_iot_network_der[-1])
print("MeMO")
print("Avg: ", np.mean(ton_iot_network_memo))
print("Last:", ton_iot_network_memo[-1])
print("Icarl")
print("Avg: ", np.mean(ton_iot_network_icarl))
print("Last:", ton_iot_network_icarl[-1])
# Out:
# Finetune
# Avg:  83.28399887084962
# Last: 89.87999725341797
# DER
# Avg:  99.13600158691406
# Last: 98.62000274658203
# MeMO
# Avg:  93.74800109863281
# Last: 71.01000213623047
# Icarl
# Avg:  99.41800079345703
# Last: 98.81999969482422

# %%
plt.plot(ton_iot_network_der, label="der")
plt.plot(ton_iot_network_finetune, label="finetune")
plt.plot(ton_iot_network_memo, label="memo")
plt.plot(ton_iot_network_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("ton_iot_network_accy_500.png")
