# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
# kdd_finetune = json.load(open("./kdd99_finetune_kdd_ann_128_Accuracy_curve.json"))
# kdd_finetune = [i[2] for i in kdd_finetune]
kdd_finetune = [100.0, 1.33, 1.13, 0.84, 0.43]
kdd_der = json.load(open("./kdd99_der_kdd_ann_128_Accuracy_curve.json"))
kdd_der = [i[2] for i in kdd_der]
kdd_der = [100.0, 100.0, 99.9, 98.66, 97.17]
kdd_memo = json.load(open("./kdd99_memo_kdd_memo_ann_128_Accuracy_curve.json"))
kdd_memo = [i[2] for i in kdd_memo]
# kdd_lwf = json.load(open("./kdd99_lwf_kdd_ann_128_Accuracy_curve.json"))
# kdd_lwf = [i[2] for i in kdd_lwf]
kdd_lwf = [100.0, 1.33, 1.13, 0.84, 0.43]
kdd_icarl = json.load(open("./kdd99_icarl_kdd_ann_128_Accuracy_curve.json"))
kdd_icarl = [i[2] for i in kdd_icarl]
kdd_icarl = [100.0, 99.99, 96.6, 93.43, 92.91]
print("Finetune")
print("Avg: ", np.mean(kdd_finetune))
print("Last:", kdd_finetune[-1])
print("DER")
print("Avg: ", np.mean(kdd_der))
print("Last:", kdd_der[-1])
print("MeMO")
print("Avg: ", np.mean(kdd_memo))
print("Last:", kdd_memo[-1])
print("Lwf")
print("Avg: ", np.mean(kdd_lwf))
print("Last:", kdd_lwf[-1])
print("Icarl")
print("Avg: ", np.mean(kdd_icarl))
print("Last:", kdd_icarl[-1])
# Out:
# Finetune
# Avg:  20.746000000000002
# Last: 0.43
# DER
# Avg:  99.14599999999999
# Last: 97.17
# MeMO
# Avg:  99.69833374023438
# Last: 99.54000091552734
# Lwf
# Avg:  20.746000000000002
# Last: 0.43
# Icarl
# Avg:  99.87333170572917
# Last: 99.83999633789062

# %%
plt.plot(kdd_der, label="der")
plt.plot(kdd_finetune, label="finetune")
plt.plot(kdd_memo, label="memo")
plt.plot(kdd_lwf, label="lwf")
plt.plot(kdd_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("kdd_accy.png")

# %%
# kdd99 plot 1000
kdd_der = json.load(open("./kdd99_der_1000_kdd_ann_128_Accuracy_curve.json"))
kdd_der = [i[2] for i in kdd_der]
kdd_memo = json.load(open("./kdd99_memo_1000_kdd_memo_ann_128_Accuracy_curve.json"))
kdd_memo = [i[2] for i in kdd_memo]
kdd_icarl = json.load(open("./kdd99_icarl_1000_kdd_ann_128_Accuracy_curve.json"))
kdd_icarl = [i[2] for i in kdd_icarl]
print("DER")
print("Avg: ", np.mean(kdd_der))
print("Last:", kdd_der[-1])
print("MeMO")
print("Avg: ", np.mean(kdd_memo))
print("Last:", kdd_memo[-1])
print("Icarl")
print("Avg: ", np.mean(kdd_icarl))
print("Last:", kdd_icarl[-1])
# Out:
# DER
# Avg:  98.81666692097981
# Last: 98.66000366210938
# MeMO
# Avg:  99.30500030517578
# Last: 99.36000061035156
# Icarl
# Avg:  99.64666748046875
# Last: 99.47000122070312

# %%
plt.plot(kdd_der, label="der")
plt.plot(kdd_memo, label="memo")
plt.plot(kdd_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("kdd_accy_1000.png")

# %%
# kdd99 plot 500
kdd_der = json.load(open("./kdd99_der_500_kdd_ann_128_Accuracy_curve.json"))
kdd_der = [i[2] for i in kdd_der]
kdd_memo = json.load(open("./kdd99_memo_500_kdd_memo_ann_128_Accuracy_curve.json"))
kdd_memo = [i[2] for i in kdd_memo]
kdd_icarl = json.load(open("./kdd99_icarl_500_kdd_ann_128_Accuracy_curve.json"))
kdd_icarl = [i[2] for i in kdd_icarl]
print("DER")
print("Avg: ", np.mean(kdd_der))
print("Last:", kdd_der[-1])
print("MeMO")
print("Avg: ", np.mean(kdd_memo))
print("Last:", kdd_memo[-1])
print("Icarl")
print("Avg: ", np.mean(kdd_icarl))
print("Last:", kdd_icarl[-1])
# Out:
# DER
# Avg:  98.23499933878581
# Last: 98.5199966430664
# MeMO
# Avg:  98.8033332824707
# Last: 99.04000091552734
# Icarl
# Avg:  98.90000025431316
# Last: 98.55000305175781

# %%
plt.plot(kdd_der, label="der")
plt.plot(kdd_memo, label="memo")
plt.plot(kdd_icarl, label="icarl")
plt.legend()
plt.xlabel("Task")
plt.ylabel("Accuracy")
plt.savefig("kdd_accy_500.png")
