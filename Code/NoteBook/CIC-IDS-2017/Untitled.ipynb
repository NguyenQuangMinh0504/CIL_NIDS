# %%
import pandas as pd



ddos_path = "../../../Dataset/CICDataset/CIC-IDS-2017/TrafficLabelling/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
ddos_table = pd.read_csv(ddos_path)

dos_path = "../../../Dataset/CICDataset/CIC-IDS-2017/TrafficLabelling/Wednesday-workingHours.pcap_ISCX.csv"
dos_table = pd.read_csv(dos_path)
ddos_table[" Label"].value_counts()
dos_table[" Label"].value_counts()
# Out:
# BENIGN              440031
# DoS Hulk            231073
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Heartbleed              11
# Name:  Label, dtype: int64

# %%
join_table = pd.concat([dos_table, ddos_table])
join_table
# Out:
#                                        Flow ID  ...   Label
# 0       192.168.10.14-209.48.71.168-49459-80-6  ...  BENIGN
# 1       192.168.10.3-192.168.10.17-389-49453-6  ...  BENIGN
# 2        192.168.10.3-192.168.10.17-88-46124-6  ...  BENIGN
# 3       192.168.10.3-192.168.10.17-389-49454-6  ...  BENIGN
# 4        192.168.10.3-192.168.10.17-88-46126-6  ...  BENIGN
# ...                                        ...  ...     ...
# 225740    192.168.10.15-72.21.91.29-61374-80-6  ...  BENIGN
# 225741    192.168.10.15-72.21.91.29-61378-80-6  ...  BENIGN
# 225742    192.168.10.15-72.21.91.29-61375-80-6  ...  BENIGN
# 225743   192.168.10.15-8.41.222.187-61323-80-6  ...  BENIGN
# 225744     192.168.10.15-8.43.72.21-61326-80-6  ...  BENIGN
#
# [918448 rows x 85 columns]
